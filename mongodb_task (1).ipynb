# %%
import pandas as pd

# %%
import pymongo
from pymongo import MongoClient
uri = 'mongodb://sanjay07:abcd123@cluster0-shard-00-00.zt5zf.mongodb.net:27017,cluster0-shard-00-01.zt5zf.mongodb.net:27017,cluster0-shard-00-02.zt5zf.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-1b9y72-shard-0&authSource=admin&retryWrites=true&w=majority'
client = MongoClient(uri)

# %%
import pymongo
client = pymongo.MongoClient("mongodb://sanjay07:abcd123@cluster0-shard-00-00.zt5zf.mongodb.net:27017,cluster0-shard-00-01.zt5zf.mongodb.net:27017,cluster0-shard-00-02.zt5zf.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-1b9y72-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.student
sanjay = db.student
#1)Find the student name who scored maximum scores in all (exam, quiz and homework)?
def max_scorer(sanjay):
  x = sanjay.aggregate([{'$unwind':'$scores'},{'$group':{"_id":"$_id","name":{"$first":"$name"},"max_score":{'$sum':"$scores.score"}}}])
  max=0
  id=0
  for i in x:
    if i['max_score']>max:
      max=i['max_score']
      id=i['_id']
      name=i['name']
    else:
      pass
  print(name," is the max scorer with a total : ",max)


max_scorer(sanjay)
# Out:
# Jessika Dagenais  is the max scorer with a total :  275.94947751518237

# %%
#2)Find students who scored below average in the exam and pass mark is 40%?
#def aggr(sanjay):
#  prcntg = sanjay.aggregate([{'$unwind':'$scores'},
 #                          {'$group':{"_id":"$_id","name":{"$first":"$name"},"max_score":{'$sum':"$scores.score"}}},
  #                         {'$addFields':{"prctg":{'$divide':["$max_score",3]}}},
   #                         {'$addFields':{"status":{"$cond":{'if' :{"$gte":["$prctg",40]},'then':"Pass",'else':"Fail"}}}}])
  #return prcntg

#prcntg=aggr(sanjay)
#for i in prcntg:
 # if i['prctg']>=40 and i['prctg']<=55:
  #    print(i)

x2=sanjay.find({ "scores.type": 'exam'})

for i in x2:
  l=[i["scores"]]
  name=i['name']
  for j in l:
    k=j[0]
    if k['score']>=40 and k['score']<=55:
      print(name,k['score'],k['type'])
# Out:
# Wilburn Spiess 44.87186330181261 exam
# Denisha Cast 45.61876862259409 exam
# Quincy Danaher 54.29841278520669 exam
# Gisela Levin 44.51211101958831 exam
# Tressa Schwing 42.17439799514388 exam
# Rosana Vales 46.2289476258328 exam
# Tamika Schildgen 45.65432764125526 exam
# Gwyneth Garling 48.36644963899371 exam
# Kayce Kenyon 44.62441703708117 exam
# Terica Brugger 42.1011312120801 exam
# Chad Rahe 40.84572027366789 exam
# Grady Zemke 51.91561300267121 exam
# Vina Matsunaga 51.38190070034149 exam
# Jenise Mcguffie 40.15210496060384 exam
# Cassi Heal 43.04310994985133 exam
# Demarcus Audette 47.42608580155614 exam
# Mercedez Garduno 49.52877007656483 exam
# Flora Duell 40.68238966626067 exam
# Wilburn Spiess 52.36963021569788 exam
# Quincy Danaher 40.53136904234401 exam
# Alix Sherrill 43.67436243299881 exam
# Dodie Staller 52.16051124848157 exam
# Tressa Schwing 54.53947018434061 exam
# Laureen Salomone 42.54322973844196 exam
# Gwyneth Garling 44.29553481758053 exam
# ...

# %%
#3)Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.
prcntg=aggr(sanjay)
for i in prcntg:
  print(i)
# Out:
# {'_id': 1, 'name': 'Aurelia Menendez', 'max_score': 184.61969202100374, 'prctg': 61.53989734033458, 'status': 'Pass'}
# {'_id': 85, 'name': 'Rae Kohout', 'max_score': 178.820098003648, 'prctg': 59.60669933454934, 'status': 'Pass'}
# {'_id': 11, 'name': 'Marcus Blohm', 'max_score': 248.5091538691126, 'prctg': 82.83638462303753, 'status': 'Pass'}
# {'_id': 74, 'name': 'Leola Lundin', 'max_score': 216.63267038170724, 'prctg': 72.21089012723574, 'status': 'Pass'}
# {'_id': 160, 'name': 'Lady Lefevers', 'max_score': 188.71235039768163, 'prctg': 62.90411679922721, 'status': 'Pass'}
# {'_id': 187, 'name': 'Devorah Smartt', 'max_score': 100.39268848940416, 'prctg': 33.46422949646806, 'status': 'Fail'}
# {'_id': 42, 'name': 'Kayce Kenyon', 'max_score': 169.44237645698738, 'prctg': 56.48079215232912, 'status': 'Pass'}
# {'_id': 177, 'name': 'Rubie Winton', 'max_score': 216.40738876682235, 'prctg': 72.13579625560745, 'status': 'Pass'}
# ...

# %%
#4)Find the total and average of the exam, quiz and homework and store them in a separate collection.
db.create_collection('total_average')
x2 = sanjay.aggregate([{'$unwind':'$scores'},{'$group':{'_id':{'type':"$scores.type"},"total:":{'$sum':"$scores.score"},"average:":{'$avg':"$scores.score"}}}])
t_a=db.total_average
for i in x2:
  print(i)
  t_a.insert_one(i)
# Out:
# {'_id': {'type': 'homework'}, 'total:': 13563.739241322297, 'average:': 67.81869620661149}
# {'_id': {'type': 'quiz'}, 'total:': 9799.344638860508, 'average:': 48.99672319430254}
# {'_id': {'type': 'exam'}, 'total:': 9734.734151900351, 'average:': 48.67367075950175}

# %%
#5)Create a new collection which consists of students who scored below average and above 40% in all the categories.
prcntg=aggr(sanjay)
db.create_collection('passed_below_average')     #collection is created once hence commented
p_a=db.passed_below_average
for i in prcntg:
  if i['prctg']>40 and i['prctg']<=55:
      print(i)
      p_a.insert_one(i)
# Out:
# {'_id': 25, 'name': 'Rudolph Domingo', 'max_score': 148.54969223180623, 'prctg': 49.51656407726875, 'status': 'Pass'}
# {'_id': 30, 'name': 'Kaila Deibler', 'max_score': 139.48229678140956, 'prctg': 46.49409892713652, 'status': 'Pass'}
# {'_id': 5, 'name': 'Wilburn Spiess', 'max_score': 134.0186975547794, 'prctg': 44.67289918492647, 'status': 'Pass'}
# {'_id': 150, 'name': 'Eugene Magdaleno', 'max_score': 126.52248166745106, 'prctg': 42.17416055581702, 'status': 'Pass'}
# {'_id': 147, 'name': 'Sadie Jernigan', 'max_score': 141.02791381651215, 'prctg': 47.00930460550405, 'status': 'Pass'}
# {'_id': 162, 'name': 'Barbera Lippman', 'max_score': 123.87383657752201, 'prctg': 41.29127885917401, 'status': 'Pass'}
# {'_id': 173, 'name': 'Vinnie Auerbach', 'max_score': 154.92533590812064, 'prctg': 51.641778636040215, 'status': 'Pass'}
# {'_id': 125, 'name': 'Marcus Blohm', 'max_score': 137.0342890305606, 'prctg': 45.678096343520195, 'status': 'Pass'}
# ...

# %%
#6)Create a new collection which consists of students who scored below the fail mark in all the categories.
prcntg=aggr(sanjay)
db.create_collection('failed')    #collection is created once hence commented
fail=db.failed
for i in prcntg:
  if i['status']=='Fail':
      print(i)
      fail.insert_one(i)
# Out:
# {'_id': 140, 'name': 'Jonie Raby', 'max_score': 102.86145390316119, 'prctg': 34.28715130105373, 'status': 'Fail'}
# {'_id': 123, 'name': 'Sanda Ryba', 'max_score': 71.27146027282822, 'prctg': 23.757153424276073, 'status': 'Fail'}
# {'_id': 175, 'name': 'Grady Zemke', 'max_score': 106.35844585670458, 'prctg': 35.45281528556819, 'status': 'Fail'}
# {'_id': 8, 'name': 'Daphne Zheng', 'max_score': 112.71677331754347, 'prctg': 37.57225777251449, 'status': 'Fail'}
# {'_id': 121, 'name': 'Salena Olmos', 'max_score': 110.68556639219787, 'prctg': 36.89518879739929, 'status': 'Fail'}
# {'_id': 187, 'name': 'Devorah Smartt', 'max_score': 100.39268848940416, 'prctg': 33.46422949646806, 'status': 'Fail'}
# {'_id': 124, 'name': 'Denisha Cast', 'max_score': 118.2341215780863, 'prctg': 39.4113738593621, 'status': 'Fail'}
# {'_id': 198, 'name': 'Timothy Harrod', 'max_score': 97.28287057232586, 'prctg': 32.42762352410862, 'status': 'Fail'}
# ...

# %%
#7)Create a new collection which consists of students who scored above pass mark in all the categories.prcntg=aggr(sanjay)
prcntg=aggr(sanjay)
db.create_collection('passed')        #collection is created once hence commented
p=db.passed
for i in prcntg:
  if i['prctg']>=40:
      print(i)
      p.insert_one(i)
# Out:
# {'_id': 22, 'name': 'Margart Vitello', 'max_score': 182.00563535570944, 'prctg': 60.66854511856982, 'status': 'Pass'}
# {'_id': 77, 'name': 'Efrain Claw', 'max_score': 175.44760101431834, 'prctg': 58.48253367143945, 'status': 'Pass'}
# {'_id': 159, 'name': 'Terica Brugger', 'max_score': 251.40459832855427, 'prctg': 83.80153277618476, 'status': 'Pass'}
# {'_id': 73, 'name': 'Devorah Smartt', 'max_score': 132.19316603930335, 'prctg': 44.06438867976778, 'status': 'Pass'}
# {'_id': 16, 'name': 'Dodie Staller', 'max_score': 120.13675287379564, 'prctg': 40.045584291265214, 'status': 'Pass'}
# {'_id': 191, 'name': 'Efrain Claw', 'max_score': 252.83317597388418, 'prctg': 84.27772532462807, 'status': 'Pass'}
# {'_id': 9, 'name': 'Sanda Ryba', 'max_score': 220.08328118626565, 'prctg': 73.36109372875522, 'status': 'Pass'}
# {'_id': 53, 'name': 'Malisa Jeanes', 'max_score': 121.1518349933377, 'prctg': 40.38394499777923, 'status': 'Pass'}
# ...

# %%
#4)Find the total and average of the exam, quiz and homework and store them in a separate collection.
#db.create_collection('total_average')
x2 = sanjay.aggregate([{'$unwind':'$scores'},{'$group':{'_id':{'type':"$scores.type"},"total:":{'$sum':"$scores.score"},"average:":{'$avg':"$scores.score"}}}])
t_a=db.total_average
for i in x2:
  print(i)
  t_a.insert_one(i)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-5-334003e2f44e> in <module>()
#       1 #4)Find the total and average of the exam, quiz and homework and store them in a separate collection.
#       2 #db.create_collection('total_average')
# ----> 3 x2 = sanjay.aggregate([{'$unwind':'$scores'},{'$group':{'_id':{'$scores.type':{"$type":"exam"}},"total:":{'$sum':"$scores.score"},"average:":{'$avg':"$scores.score"}}}])
#       4 #t_a=db.total_average
#       5 for i in x2:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in aggregate(self, pipeline, session, **kwargs)
#    1974                                    session=s,
#    1975                                    explicit_session=session is not None,
# -> 1976                                    **kwargs)
#    1977
#    1978     def aggregate_raw_batches(self, pipeline, session=None, **kwargs):
#
# ...
